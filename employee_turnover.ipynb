# %% [markdown]
# <a href="https://colab.research.google.com/github/nithishravan/Logicstic_Regression/blob/main/employee_turnover.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

data=pd.read_csv("/content/WA_Fn-UseC_-HR-Employee-Attrition.csv")
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
from sklearn import metrics
x=data[["Age","MonthlyIncome","PerformanceRating","YearsAtCompany","TotalWorkingYears"]]
y=data["Attrition"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4)
model=LogisticRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
x_test["attriction"]=y_pred
x_test
# Out:
#       Age  MonthlyIncome  PerformanceRating  YearsAtCompany  \
# 124    31           6172                  3               7
# 551    39           6389                  3               8
# 462    34           5337                  3              10
# 655    33           2277                  3               4
# 57     35           4014                  3               2
# ...   ...            ...                ...             ...
# 1432   37          13744                  4              16
# 104    37           5163                  3               1
# 863    33           3600                  3               5
# 193    43           2089                  3               5
# 729    35          10388                  3              16
#
#       TotalWorkingYears attriction
# 124                  12         No
# 551                  12         No
# 462                  10         No
# 655                   7         No
# 57                    4         No
# ...
